# %% [markdown]
# ### Compare runs, choose a model, and deploy it to a REST API
#
# In this project, you will:
#
# - Run a hyperparameter sweep on a training script
#
# - Compare the results of the runs in the MLflow UI
#
# - Choose the best run and register it as a model
#
# - Deploy the model to a REST API
#
# - Build a container image suitable for deployment to a cloud platform

# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
## load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into training,validation and test sets

train,test=train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
train[['quality']].values.ravel()
# Out:
# array([6, 6, 5, ..., 6, 6, 8], shape=(3673,))

# %%
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel()

## test dataset
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

## splitting this train data into train and validation

train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
np.mean(train_x,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
train_x.shape[1]
# Out:
# 11

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %% [markdown]
# ## ANN Model with Architecture

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
# %pip install -U mlflow
# Out:
# Requirement already satisfied: mlflow in d:\workandprojects\mlflow_starting\starter\lib\site-packages (3.3.2)
# Requirement already satisfied: mlflow-skinny==3.3.2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (3.3.2)
# Requirement already satisfied: mlflow-tracing==3.3.2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (3.3.2)
# Requirement already satisfied: Flask<4 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (1.16.5)
# Requirement already satisfied: cryptography<46,>=43.0.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: matplotlib<4 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (3.10.6)
# Requirement already satisfied: numpy<3 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (2.2.6)
# Requirement already satisfied: pandas<3 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (2.3.2)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (1.7.1)
# Requirement already satisfied: scipy<2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (2.0.43)
# Requirement already satisfied: waitress<4 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.65.0)
# Requirement already satisfied: fastapi<1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.116.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (1.36.0)
# Requirement already satisfied: packaging<26 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (6.32.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (2.11.7)
# Requirement already satisfied: pyyaml<7,>=5.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from mlflow-skinny==3.3.2->mlflow) (0.35.0)
# Requirement already satisfied: Mako in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: tomli in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (2.2.1)
# Requirement already satisfied: colorama in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.3.2->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=1.14 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from cryptography<46,>=43.0.0->mlflow) (1.17.1)
# Requirement already satisfied: google-auth~=2.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (2.40.3)
# Requirement already satisfied: pywin32>=304 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: urllib3>=1.26.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from fastapi<1->mlflow-skinny==3.3.2->mlflow) (0.47.3)
# Requirement already satisfied: blinker>=1.9.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.3.2->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from graphene<4->mlflow) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.3.2->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from matplotlib<4->mlflow) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.3.2->mlflow) (0.57b0)
# Requirement already satisfied: pytz>=2020.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.2->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.2->mlflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.2->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow) (4.10.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==3.3.2->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from uvicorn<1->mlflow-skinny==3.3.2->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in d:\workandprojects\mlflow_starting\starter\lib\site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 18s 411ms/step - loss: 30.5173 - root_mean_squared_error: 5.5242
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.8150 - root_mean_squared_error: 5.4603
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 29.1444 - root_mean_squared_error: 5.3986 - val_loss: 27.8836 - val_root_mean_squared_error: 5.2805
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 29.5372 - root_mean_squared_error: 5.4348
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.7234 - root_mean_squared_error: 5.2650
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.8062 - root_mean_squared_error: 5.1775 - val_loss: 25.6155 - val_root_mean_squared_error: 5.0612
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 26.3142 - root_mean_squared_error: 5.1297
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.7096 - root_mean_squared_error: 5.0703
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 24.6507 - root_mean_squared_error: 4.9649 - val_loss: 23.5166 - val_root_mean_squared_error: 4.8494
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 24.1397 - root_mean_squared_error: 4.9132
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.5166 - root_mean_squared_error: 4.8494
#
#   0%|          | 0/4 [00:01<?, ?trial/s, best loss=?]
# 2025/09/04 19:55:05 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run melodic-ray-788 at: http://127.0.0.1:5000/#/experiments/482579197882226087/runs/381ab0a40f904f7f874db6eef6bdcd68
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/482579197882226087
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 16s 361ms/step - loss: 30.9447 - root_mean_squared_error: 5.5628
# 39/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25.3646 - root_mean_squared_error: 5.0324
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.2417 - root_mean_squared_error: 4.6089 - val_loss: 15.3822 - val_root_mean_squared_error: 3.9220
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 13.5193 - root_mean_squared_error: 3.6769
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.2342 - root_mean_squared_error: 3.6366
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.4806 - root_mean_squared_error: 3.3883 - val_loss: 8.2802 - val_root_mean_squared_error: 2.8775
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0671 - root_mean_squared_error: 2.8403
# 35/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2534 - root_mean_squared_error: 2.6925
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2784 - root_mean_squared_error: 2.5057 - val_loss: 4.7960 - val_root_mean_squared_error: 2.1900
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6404 - root_mean_squared_error: 2.1542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7960 - root_mean_squared_error: 2.1900
#
#  25%|██▌       | 1/4 [00:11<00:32, 10.75s/trial, best loss: 4.849394798278809]
# 2025/09/04 19:55:16 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run nimble-gull-371 at: http://127.0.0.1:5000/#/experiments/482579197882226087/runs/19549557fb2f446d86ddbb708bdfb272
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/482579197882226087
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 33.8811 - root_mean_squared_error: 5.8207
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.1716 - root_mean_squared_error: 5.7591
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31.4038 - root_mean_squared_error: 5.6039 - val_loss: 28.8041 - val_root_mean_squared_error: 5.3669
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 26.9600 - root_mean_squared_error: 5.1923
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27.6052 - root_mean_squared_error: 5.2539
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.2407 - root_mean_squared_error: 5.1226 - val_loss: 24.0577 - val_root_mean_squared_error: 4.9049
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 21.2428 - root_mean_squared_error: 4.6090
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22.7206 - root_mean_squared_error: 4.7665
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.9102 - root_mean_squared_error: 4.6808 - val_loss: 20.0587 - val_root_mean_squared_error: 4.4787
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 20.4349 - root_mean_squared_error: 4.5205
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.0587 - root_mean_squared_error: 4.4787
#
#  50%|█████     | 2/4 [00:21<00:19,  9.79s/trial, best loss: 2.1899802684783936]
# 2025/09/04 19:55:25 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run clumsy-bee-175 at: http://127.0.0.1:5000/#/experiments/482579197882226087/runs/0a747264165a4fc4b2f2b25ed3fd37d0
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/482579197882226087
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 38.1452 - root_mean_squared_error: 6.1762
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.5587 - root_mean_squared_error: 6.2894
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 39.1689 - root_mean_squared_error: 6.2585 - val_loss: 39.0193 - val_root_mean_squared_error: 6.2465
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 42.8027 - root_mean_squared_error: 6.5424
# 42/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 38.9906 - root_mean_squared_error: 6.2439
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38.4781 - root_mean_squared_error: 6.2031 - val_loss: 38.3227 - val_root_mean_squared_error: 6.1905
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 36.7620 - root_mean_squared_error: 6.0632
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37.7540 - root_mean_squared_error: 6.1444
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.8017 - root_mean_squared_error: 6.1483 - val_loss: 37.6414 - val_root_mean_squared_error: 6.1353
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 38.0626 - root_mean_squared_error: 6.1695
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.6414 - root_mean_squared_error: 6.1353
#
#  75%|███████▌  | 3/4 [00:30<00:09,  9.57s/trial, best loss: 2.1899802684783936]
# 2025/09/04 19:55:34 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run unique-carp-747 at: http://127.0.0.1:5000/#/experiments/482579197882226087/runs/614ce18b14a54a59b1b79a1965a665a9
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/482579197882226087
#
# 100%|██████████| 4/4 [00:38<00:00,  9.63s/trial, best loss: 2.1899802684783936]
# 2025/09/04 19:55:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Best parameters: {'lr': np.float64(0.0005829442316902937), 'momentum': np.float64(0.13249110873159342)}
# Best eval rmse: 2.1899802684783936
# 🏃 View run nervous-bear-363 at: http://127.0.0.1:5000/#/experiments/482579197882226087/runs/90d306a5ffbb4042a1ff036222f8c3ef
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/482579197882226087

# %%
model_uri = "runs:/bef77e9e3f9c430b961d025dc700d1e1/model"

# %%
loaded_model = mlflow.pyfunc.load_model(model_uri)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(test_x))
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts: 100%|██████████| 7/7 [00:00<00:00, 852.60it/s]
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[5.880267 ],
#        [6.5813885],
#        [6.720609 ],
#        ...,
#        [6.203083 ],
#        [6.718503 ],
#        [6.0712175]], shape=(1225, 1), dtype=float32)

# %%
## Register in the model registry
mlflow.register_model(model_uri,"wine-quality")
# Out:
# Successfully registered model 'wine-quality'.
# 2025/09/04 19:51:42 WARNING mlflow.tracking._model_registry.fluent: Run with id bef77e9e3f9c430b961d025dc700d1e1 has no artifacts at artifact path 'model', registering model based on models:/m-3722838f102f45f5bfcd3fb1d3a3ef34 instead
# 2025/09/04 19:51:42 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: wine-quality, version 1
# Created version '1' of model 'wine-quality'.
# <ModelVersion: aliases=[], creation_timestamp=1756997502120, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1756997502120, metrics=None, model_id=None, name='wine-quality', params=None, run_id='bef77e9e3f9c430b961d025dc700d1e1', run_link='', source='models:/m-3722838f102f45f5bfcd3fb1d3a3ef34', status='READY', status_message=None, tags={}, user_id='', version='1'>
